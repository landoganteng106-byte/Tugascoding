# %%
#DwikaPrilando
#PSTI B



x = 32 #uat variabel skalar x dan simpan suatu nillai skalar

# %%
type(x) #tampilkan tipe data dari x
# Out:
# int

# %%
y = 20 #buat variabel skalar y dan simpan suatu nilai skalar

type(y) #tampilkan tipe data dari y
g = x + y #jumlahkan x+y

print(g) #Tampilkan hasil penjumlahan
# Out:
# 52

# %%
x_float = 30.5

j = x_float + y
print(j)

type(x_float)
# Out:
# 50.5
# float

# %%
import tensorflow as t

# %%
x_pt = t.constant(25)
x_pt
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=25>

# %%
x_pt.shape
# Out:
# TensorShape([])

# %%
y_tf = t.Variable(3, dtype=t.int16)

# %%
x_tf = t.Variable(3, dtype=t.int8)

# %%
x_tf + t.cast(y_tf, t.int8)
# Out:
# <tf.Tensor: shape=(), dtype=int8, numpy=6>

# %%
tf_sum = t.add(x_tf, t.cast(y_tf, t.int8))
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int8, numpy=6>

# %%
tf_sum.numpy() # note that NumPy operations automatically convert tensors to NumPy arrays, and vice versa
# Out:
# np.int8(6)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int8

# %%
tf_float = t.Variable(25., dtype=t.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=25.0>
